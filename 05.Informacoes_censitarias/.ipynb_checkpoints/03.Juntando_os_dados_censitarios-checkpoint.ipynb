# %% [markdown]
# # Jutandos os Dados censitários ao Dataset

# %%
import geopandas as gpd

# %%
setor = gpd.read_file('../01.Dados/Mapas/RJ-SETOR/RJ-SETOR.shp')
setor
# Out:
#           ID1       CD_GEOCODI    TIPO    CD_GEOCODB         NM_BAIRRO  \
# 0      408153  330455705250108  URBANO  330455705117  Jardim Guanabara
# 1      408157  330455705250112  URBANO  330455705117  Jardim Guanabara
# 2      408158  330455705250113  URBANO  330455705117  Jardim Guanabara
# 3      408149  330455705250104  URBANO  330455705117  Jardim Guanabara
# 4      408150  330455705250105  URBANO  330455705117  Jardim Guanabara
# ...       ...              ...     ...           ...               ...
# 10499  405177  330455705230578  URBANO  330455705104          Inhoaíba
# 10500  405178  330455705230579  URBANO  330455705102      Campo Grande
# 10501  405179  330455705230580  URBANO  330455705102      Campo Grande
# 10502  405180  330455705230581  URBANO  330455705105            Cosmos
# 10503  405181  330455705230582  URBANO  330455705105            Cosmos
#
#       CD_GEOCODD      NM_DISTRIT CD_GEOCODS          NM_SUBDIST CD_GEOCODM  \
# 0      330455705  RIO DE JANEIRO  330455705  ILHA DO GOVERNADOR    3304557
# 1      330455705  RIO DE JANEIRO  330455705  ILHA DO GOVERNADOR    3304557
# 2      330455705  RIO DE JANEIRO  330455705  ILHA DO GOVERNADOR    3304557
# 3      330455705  RIO DE JANEIRO  330455705  ILHA DO GOVERNADOR    3304557
# 4      330455705  RIO DE JANEIRO  330455705  ILHA DO GOVERNADOR    3304557
# ...          ...             ...        ...                 ...        ...
# 10499  330455705  RIO DE JANEIRO  330455705        CAMPO GRANDE    3304557
# 10500  330455705  RIO DE JANEIRO  330455705        CAMPO GRANDE    3304557
# 10501  330455705  RIO DE JANEIRO  330455705        CAMPO GRANDE    3304557
# 10502  330455705  RIO DE JANEIRO  330455705        CAMPO GRANDE    3304557
# 10503  330455705  RIO DE JANEIRO  330455705        CAMPO GRANDE    3304557
#
#        ...  V004     V005         V006     V007         V008     V009  \
# 0      ...  2.03  3197.22  30441095.44  3955.19  34678115.89  2532.07
# 1      ...  2.02  2939.27  11625233.69  4082.31  11478517.02  1868.44
# 2      ...  1.74  4607.17  27747188.04  4825.07  28009914.76  2373.90
# 3      ...  2.11  4514.60  69474357.33  5281.78  77279356.46  2325.76
# 4      ...  1.57  3681.71  10261605.38  3929.35   9977475.56  2365.34
# ...    ...   ...      ...          ...      ...          ...      ...
# 10499  ...  3.08   649.95    250595.04   771.82    203098.33   404.80
# 10500  ...  1.63  1677.27   5707100.74  1971.93   6131528.41  1071.21
# 10501  ...  1.24  3767.70  13016750.05  4043.39  12853494.85  2015.66
# 10502  ...  1.63  1808.34   1779159.08  1888.27   1706471.80   868.49
# 10503  ...  2.18  1198.42    877596.21  1249.67    850994.26   681.82
#
#               V010     V011         V012  \
# 0      17394403.77  3603.87  20901128.23
# 1       7840859.89  3183.57   9178699.99
# 2      15297946.52  3596.82  18791839.98
# 3      30455188.88  3839.47  44512674.58
# 4      15099508.74  3315.75  18021853.15
# ...            ...      ...          ...
# 10499    211604.46   688.36    164401.58
# 10500   3177761.60  1663.28   3951848.89
# 10501   8169306.03  3118.58   9203043.73
# 10502   1377545.75  1514.94   1423718.61
# 10503    782046.07  1090.41    805207.24
#
#                                                 geometry
# 0      POLYGON ((685.4591043133208 7475.550996104756,...
# 1      POLYGON ((685.0191942056239 7475.929957812803,...
# 2      POLYGON ((684.9021460641951 7475.510962820837,...
# 3      POLYGON ((684.9062583766679 7476.316936596705,...
# 4      POLYGON ((685.055252568599 7476.374943694936, ...
# ...                                                  ...
# 10499  POLYGON ((643.6314287480265 7464.847037630541,...
# 10500  POLYGON ((648.8553919083637 7466.08320959296, ...
# 10501  POLYGON ((648.7443035068189 7470.666660824385,...
# 10502  POLYGON ((641.4140491520388 7466.373530296078,...
# 10503  POLYGON ((641.4038032770358 7465.605100245036,...
#
# [10504 rows x 47 columns]

# %%
rj = gpd.read_file('../01.Dados/Mapas/RJ-MINUC/RJ-MINUC.shp')
geo_dados = gpd.read_file('../01.Dados/Mapas/RJ-DATASET/DATASET.shp')

# %%
#setor = setor.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')
rj = rj.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')
geo_dados = geo_dados.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')

# %%
base = setor.plot(color='white',edgecolor='gray',figsize=(15,8))
geo_dados.plot(ax=base,color='blue',markersize=1)

# %%
geo_dados.shape
# Out:
# (4513, 17)

# %%
# join espacial
from geopandas.tools import sjoin
geo_dados = gpd.sjoin(geo_dados, setor, how='left', op='within')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-53a29e7f8575> in <module>
#       1 # join espacial
#       2 from geopandas.tools import sjoin
# ----> 3 geo_dados = gpd.sjoin(geo_dados, setor, how='left', op='within')
#
# ~/.local/lib/python3.7/site-packages/geopandas/tools/sjoin.py in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#      27         Binary predicate, one of {'intersects', 'contains', 'within'}.
#      28         See http://shapely.readthedocs.io/en/latest/manual.html#binary-predicates.
# ---> 29     lsuffix : string, default 'left'
#      30         Suffix to apply to overlapping column names (left GeoDataFrame).
#      31     rsuffix : string, default 'right'
#
# ModuleNotFoundError: No module named 'rtree'

# %%
geo_dados.shape
# Out:
# (4513, 17)
